# %% [markdown]
# ### Statistics Lab

# %% [markdown]
# Why are our best and most experienced employees leaving prematurely? Have fun with this database and try to predict which valuable employees will leave next. Fields in the dataset include:
#
# * Last evaluation
# * Number of projects
# * Average monthly hours
# * Time spent at the company
# * Whether they have had a work accident
# * Whether they have had a promotion in the last 5 years
# * Department
# * Salary
# * Whether the employee has left
#
# ** This dataset is simulated **
#
# Obtained from Kaggle https://www.kaggle.com/ludobenistant/hr-analytics

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
hr = pd.read_csv("data/HR_comma_sep.csv")

# %%
hr.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_monthly_hours  \
# 0                0.38             0.53               2                    157
# 1                0.80             0.86               5                    262
# 2                0.11             0.88               7                    272
# 3                0.72             0.87               5                    223
# 4                0.37             0.52               2                    159
#
#    time_spent_company  work_accident  left  promotion_last_5years department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %% [markdown]
# #### 1. What is the mean average monthly hours worked by an employee?

# %%
hr.mean()
# Out:
# satisfaction_level         0.612834
# last_evaluation            0.716102
# number_project             3.803054
# average_monthly_hours    201.050337
# time_spent_company         3.498233
# work_accident              0.144610
# left                       0.238083
# promotion_last_5years      0.021268
# dtype: float64

# %% [markdown]
# #### 2. What is the median satisfaction level for employees?

# %%
hr.median()
# Out:
# satisfaction_level         0.64
# last_evaluation            0.72
# number_project             4.00
# average_monthly_hours    200.00
# time_spent_company         3.00
# work_accident              0.00
# left                       0.00
# promotion_last_5years      0.00
# dtype: float64

# %% [markdown]
# #### 3. What is the most common / mode number of projects worked on?

# %%
hr.mode()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_monthly_hours  \
# 0                 0.1             0.55             4.0                    135
# 1                 NaN              NaN             NaN                    156
#
#    time_spent_company  work_accident  left  promotion_last_5years department  \
# 0                 3.0            0.0   0.0                    0.0      sales
# 1                 NaN            NaN   NaN                    NaN        NaN
#
#   salary
# 0    low
# 1    NaN

# %% [markdown]
# #### 4. Create boxplots of satisfaction level and last evaluation

# %%
hr[['satisfaction_level', 'last_evaluation']].plot(kind='box')

# %% [markdown]
# #### 5. What is the correlation between employee satisfaction and their last evaluation?

# %%
hr[['satisfaction_level', 'last_evaluation']].corr()
# Out:
#                     satisfaction_level  last_evaluation
# satisfaction_level            1.000000         0.105021
# last_evaluation               0.105021         1.000000

# %% [markdown]
# #### 6. Plot a histogram of the average monthly hours with 20 bins

# %%
plt.hist(hr.average_monthly_hours, bins=20)
# Out:
# (array([  187.,   180.,   281.,   959.,  1338.,  1395.,   833.,   889.,
#           885.,   743.,   805.,   907.,   919.,   987.,  1089.,  1151.,
#           793.,   334.,   154.,   170.]),
#  array([  96. ,  106.7,  117.4,  128.1,  138.8,  149.5,  160.2,  170.9,
#          181.6,  192.3,  203. ,  213.7,  224.4,  235.1,  245.8,  256.5,
#          267.2,  277.9,  288.6,  299.3,  310. ]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# #### 7. Plot a density plot of the satisfaction level

# %%
hr.satisfaction_level.plot(kind='density')

# %% [markdown]
# #### 8. What is the Skew and Kurtosis of the average monthly hours variable?

# %%
hr.average_monthly_hours.skew()
# Out:
# 0.052841989416324203

# %%
hr.average_monthly_hours.kurt()
# Out:
# -1.1349815681924558

# %% [markdown]
# #### 9. Which variable has the highest correlation with whether the employee has left?

# %%
import numpy as np
s = np.abs(hr.corr()["left"])
np.abs(hr.corr()["left"])
# Out:
# satisfaction_level       0.388375
# last_evaluation          0.006567
# number_project           0.023787
# average_monthly_hours    0.071287
# time_spent_company       0.144822
# work_accident            0.154622
# left                     1.000000
# promotion_last_5years    0.061788
# Name: left, dtype: float64

# %% [markdown]
# #### 10. Which departments have the most number of employees who have left?

# %%
hr[hr["left"]==1]
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# 7                    0.92             0.85               5
# 8                    0.89             1.00               5
# 9                    0.42             0.53               2
# 10                   0.45             0.54               2
# 11                   0.11             0.81               6
# 12                   0.84             0.92               4
# 13                   0.41             0.55               2
# 14                   0.36             0.56               2
# 15                   0.38             0.54               2
# 16                   0.45             0.47               2
# 17                   0.78             0.99               4
# 18                   0.45             0.51               2
# 19                   0.76             0.89               5
# 20                   0.11             0.83               6
# 21                   0.38             0.55               2
# 22                   0.09             0.95               6
# 23                   0.46             0.57               2
# 24                   0.40             0.53               2
# 25                   0.89             0.92               5
# 26                   0.82             0.87               4
# 27                   0.40             0.49               2
# 28                   0.41             0.46               2
# 29                   0.38             0.50               2
# ...                   ...              ...             ...
# 14969                0.43             0.46               2
# 14970                0.78             0.93               4
# 14971                0.39             0.45               2
# 14972                0.11             0.97               6
# 14973                0.36             0.52               2
# 14974                0.36             0.54               2
# 14975                0.10             0.79               7
# 14976                0.40             0.47               2
# 14977                0.81             0.85               4
# 14978                0.40             0.47               2
# 14979                0.09             0.93               6
# 14980                0.76             0.89               5
# 14981                0.73             0.93               5
# 14982                0.38             0.49               2
# 14983                0.72             0.84               5
# 14984                0.40             0.56               2
# 14985                0.91             0.99               5
# 14986                0.85             0.85               4
# 14987                0.90             0.70               5
# 14988                0.46             0.55               2
# 14989                0.43             0.57               2
# 14990                0.89             0.88               5
# 14991                0.09             0.81               6
# 14992                0.40             0.48               2
# 14993                0.76             0.83               6
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_monthly_hours  time_spent_company  work_accident  left  \
# 0                        157                   3              0     1
# 1                        262                   6              0     1
# 2                        272                   4              0     1
# 3                        223                   5              0     1
# 4                        159                   3              0     1
# 5                        153                   3              0     1
# 6                        247                   4              0     1
# 7                        259                   5              0     1
# 8                        224                   5              0     1
# 9                        142                   3              0     1
# 10                       135                   3              0     1
# 11                       305                   4              0     1
# 12                       234                   5              0     1
# 13                       148                   3              0     1
# 14                       137                   3              0     1
# 15                       143                   3              0     1
# 16                       160                   3              0     1
# 17                       255                   6              0     1
# 18                       160                   3              1     1
# 19                       262                   5              0     1
# 20                       282                   4              0     1
# 21                       147                   3              0     1
# 22                       304                   4              0     1
# 23                       139                   3              0     1
# 24                       158                   3              0     1
# 25                       242                   5              0     1
# 26                       239                   5              0     1
# 27                       135                   3              0     1
# 28                       128                   3              0     1
# 29                       132                   3              0     1
# ...                      ...                 ...            ...   ...
# 14969                    157                   3              0     1
# 14970                    225                   5              0     1
# 14971                    140                   3              0     1
# 14972                    310                   4              0     1
# 14973                    143                   3              0     1
# 14974                    153                   3              0     1
# 14975                    310                   4              0     1
# 14976                    136                   3              0     1
# 14977                    251                   6              0     1
# 14978                    144                   3              0     1
# 14979                    296                   4              0     1
# 14980                    238                   5              0     1
# 14981                    162                   4              0     1
# 14982                    137                   3              0     1
# 14983                    257                   5              0     1
# 14984                    148                   3              0     1
# 14985                    254                   5              0     1
# 14986                    247                   6              0     1
# 14987                    206                   4              0     1
# 14988                    145                   3              0     1
# 14989                    159                   3              1     1
# 14990                    228                   5              1     1
# 14991                    257                   4              0     1
# 14992                    155                   3              0     1
# 14993                    293                   6              0     1
# 14994                    151                   3              0     1
# 14995                    160                   3              0     1
# 14996                    143                   3              0     1
# 14997                    280                   4              0     1
# 14998                    158                   3              0     1
#
#        promotion_last_5years  department  salary
# 0                          0       sales     low
# 1                          0       sales  medium
# 2                          0       sales  medium
# 3                          0       sales     low
# 4                          0       sales     low
# 5                          0       sales     low
# 6                          0       sales     low
# 7                          0       sales     low
# 8                          0       sales     low
# 9                          0       sales     low
# 10                         0       sales     low
# 11                         0       sales     low
# 12                         0       sales     low
# 13                         0       sales     low
# 14                         0       sales     low
# 15                         0       sales     low
# 16                         0       sales     low
# 17                         0       sales     low
# 18                         1       sales     low
# 19                         0       sales     low
# 20                         0       sales     low
# 21                         0       sales     low
# 22                         0       sales     low
# 23                         0       sales     low
# 24                         0       sales     low
# 25                         0       sales     low
# 26                         0       sales     low
# 27                         0       sales     low
# 28                         0  accounting     low
# 29                         0  accounting     low
# ...                      ...         ...     ...
# 14969                      0       sales  medium
# 14970                      0       sales  medium
# 14971                      0       sales  medium
# 14972                      0  accounting  medium
# 14973                      0  accounting  medium
# 14974                      0  accounting  medium
# 14975                      0          hr  medium
# 14976                      0          hr  medium
# 14977                      0          hr  medium
# 14978                      0          hr  medium
# 14979                      0   technical  medium
# 14980                      0   technical    high
# 14981                      0   technical     low
# 14982                      0   technical  medium
# 14983                      0   technical  medium
# 14984                      0   technical  medium
# 14985                      0   technical  medium
# 14986                      0   technical     low
# 14987                      0   technical     low
# 14988                      0   technical     low
# 14989                      0   technical     low
# 14990                      0     support     low
# 14991                      0     support     low
# 14992                      0     support     low
# 14993                      0     support     low
# 14994                      0     support     low
# 14995                      0     support     low
# 14996                      0     support     low
# 14997                      0     support     low
# 14998                      0     support     low
#
# [3571 rows x 10 columns]

# %% [markdown]
# #### 11. Which column(s) requires dummy variables? Create the dummy variables for the column and append to the dataset

# %%
dept_dummies = pd.get_dummies(hr["department"], prefix="dept", drop_dirst=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-e47d5afcc05a> in <module>()
# ----> 1 dept_dummies = pd.get_dummies(hr["department"], prefix="dept", drop_dirst=True)
#
# TypeError: get_dummies() got an unexpected keyword argument 'drop_dirst'
