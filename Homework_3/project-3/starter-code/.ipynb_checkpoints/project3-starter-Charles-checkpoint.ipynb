# %% [markdown]
# # Project 3
#
# In this project, you will perform a logistic regression on the admissions data we've been working with in projects 1 and 2.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

import pylab as pl
import numpy as np

# %%
df_raw = pd.read_csv("../assets/admissions.csv")
df = df_raw.dropna() 
print df.head()
# Out:
#    admit    gre   gpa  prestige
# 0      0  380.0  3.61       3.0
# 1      1  660.0  3.67       3.0
# 2      1  800.0  4.00       1.0
# 3      1  640.0  3.19       4.0
# 4      0  520.0  2.93       4.0

# %% [markdown]
# ## Part 1. Frequency Tables
#
# #### 1. Let's create a frequency table of our variables

# %%
# frequency table for prestige and whether or not someone was admitted

freq_df = pd.crosstab(index=df["admit"], columns=df["prestige"])
freq_df
# Out:
# prestige  1.0  2.0  3.0  4.0
# admit
# 0          28   95   93   55
# 1          33   53   28   12

# %% [markdown]
# ## Part 2. Return of dummy variables

# %% [markdown]
# #### 2.1 Create class or dummy variables for prestige

# %%
dummy_rank = pd.get_dummies(df["prestige"]) 
dummy_rank.columns = ['prestige_1', 'prestige_2', 'prestige_3', 'prestige_4']
df_dummy = df.join(dummy_rank)
df_dummy.drop('prestige', axis=1, inplace=True)
df_dummy
# Out:
#      admit    gre   gpa  prestige_1  prestige_2  prestige_3  prestige_4
# 0        0  380.0  3.61           0           0           1           0
# 1        1  660.0  3.67           0           0           1           0
# 2        1  800.0  4.00           1           0           0           0
# 3        1  640.0  3.19           0           0           0           1
# 4        0  520.0  2.93           0           0           0           1
# 5        1  760.0  3.00           0           1           0           0
# 6        1  560.0  2.98           1           0           0           0
# 7        0  400.0  3.08           0           1           0           0
# 8        1  540.0  3.39           0           0           1           0
# 9        0  700.0  3.92           0           1           0           0
# 10       0  800.0  4.00           0           0           0           1
# 11       0  440.0  3.22           1           0           0           0
# ...

# %% [markdown]
# #### 2.2 When modeling our class variables, how many do we need?

# %% [markdown]
# Answer: 3

# %% [markdown]
# ## Part 3. Hand calculating odds ratios
#
# Develop your intuition about expected outcomes by hand calculating odds ratios.

# %%
cols_to_keep = ['admit', 'gre', 'gpa']
handCalc = df[cols_to_keep].join(dummy_rank.ix[:, 'prestige_1':])
print handCalc.head()
# Out:
#    admit    gre   gpa  prestige_1  prestige_2  prestige_3  prestige_4
# 0      0  380.0  3.61           0           0           1           0
# 1      1  660.0  3.67           0           0           1           0
# 2      1  800.0  4.00           1           0           0           0
# 3      1  640.0  3.19           0           0           0           1
# 4      0  520.0  2.93           0           0           0           1

# %%
#crosstab prestige 1 admission 
# frequency table cutting prestige and whether or not someone was admitted
df_freq = pd.crosstab(index=dummy_rank["admit"], columns=dummy_rank['prestige_1'])
df_freq.iloc[0:1, 0:2]
### I don't understand what happened, tried troubleshooting. It worked earlier then suddenly didn't work anymore.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-ed9988ca28b5> in <module>()
#       1 #crosstab prestige 1 admission
#       2 # frequency table cutting prestige and whether or not someone was admitted
# ----> 3 df_freq = pd.crosstab(index=dummy_rank["admit"], columns=dummy_rank['prestige_1'])
#       4 df_freq.iloc[0:1, 0:2]
#       5 ### I don't understand what happened, tried troubleshooting. It worked earlier then suddenly didn't work anymore.
#
# C:\Users\Charles\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# C:\Users\Charles\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
# ...

# %% [markdown]
# #### 3.1 Use the cross tab above to calculate the odds of being admitted to grad school if you attended a #1 ranked college

# %% [markdown]
# 33/61 = 54.10% chance of admission

# %% [markdown]
# #### 3.2 Now calculate the odds of admission if you did not attend a #1 ranked college

# %% [markdown]
# 93/336 = 27% chance of admission

# %% [markdown]
# #### 3.3 Calculate the odds ratio

# %% [markdown]
# 3.079

# %% [markdown]
# #### 3.4 Write this finding in a sentenance:

# %% [markdown]
# Answer: If you attended a #1 ranked college you were 3.079 times more likely to be admitted to grad school than if you didn't attend a #1 ranked college

# %% [markdown]
# #### 3.5 Print the cross tab for prestige_4

# %%
df_freq = pd.crosstab(index=dummy_rank["admit"], columns=dummy_rank['prestige'],)
print(df_freq.loc[:, 4])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-e53781ccf32d> in <module>()
# ----> 1 df_freq = pd.crosstab(index=dummy_rank["admit"], columns=dummy_rank['prestige'],)
#       2 print(df_freq.loc[:, 4])
#
# C:\Users\Charles\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# C:\Users\Charles\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# ...

# %% [markdown]
# #### 3.6 Calculate the OR

# %% [markdown]
# 1.349

# %% [markdown]
# #### 3.7 Write this finding in a sentence

# %% [markdown]
# Answer: If you attended a #4 ranked college you were 1.349 times more likely to be admitted to grad school than if you didn't attend a #4 ranked college

# %% [markdown]
# ## Part 4. Analysis

# %%
# create a clean data frame for the regression
cols_to_keep = ['admit', 'gre', 'gpa']
data = df[cols_to_keep].join(dummy_rank.ix[:, 'prestige_2':])
print data.head()
# Out:
#    admit    gre   gpa  prestige_2  prestige_3  prestige_4
# 0      0  380.0  3.61           0           1           0
# 1      1  660.0  3.67           0           1           0
# 2      1  800.0  4.00           0           0           0
# 3      1  640.0  3.19           0           0           1
# 4      0  520.0  2.93           0           0           1

# %% [markdown]
# We're going to add a constant term for our Logistic Regression. The statsmodels function we're going to be using requires that intercepts/constants are specified explicitly.

# %%
# manually add the intercept
data['intercept'] = 1.0
# statsmodels requires nitercept to be specified. y = mx+c < if your c is not 1 it will affect the prediction of the y. By making c = 1 your formula can be shortened to y = mx

# %% [markdown]
# #### 4.1 Set the covariates to a variable called train_cols

# %%
train_cols = data.columns[1:]
train_cols
# Out:
# Index([u'gre', u'gpa', u'prestige_2', u'prestige_3', u'prestige_4',
#        u'intercept'],
#       dtype='object')

# %% [markdown]
# #### 4.2 Fit the model

# %%
lm_f = smf.logit(formula = 'admit ~ gre + gpa + prestige_2 + prestige_3 + prestige_4', data=data ).fit() # DONT FORGET TO FIT
# Out:
# Optimization terminated successfully.
#          Current function value: 0.573854
#          Iterations 6

# %% [markdown]
# #### 4.3 Print the summary results

# %%
lm_f.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                  admit   No. Observations:                  397
# Model:                          Logit   Df Residuals:                      391
# Method:                           MLE   Df Model:                            5
# Date:                Sun, 02 Jul 2017   Pseudo R-squ.:                 0.08166
# Time:                        12:07:48   Log-Likelihood:                -227.82
# converged:                       True   LL-Null:                       -248.08
#                                         LLR p-value:                 1.176e-07
# ...
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -3.8769      1.142     -3.393      0.001        -6.116    -1.638
# gre            0.0022      0.001      2.028      0.043      7.44e-05     0.004
# ...

# %% [markdown]
# #### 4.4 Calculate the odds ratios of the coeffiencents and their 95% CI intervals
#
# hint 1: np.exp(X)
#
# hint 2: conf['OR'] = params
#
#            conf.columns = ['2.5%', '97.5%', 'OR']

# %%
np.exp(lm_f.params)
# Out:
# Intercept     0.020716
# gre           1.002221
# gpa           2.180027
# prestige_2    0.506548
# prestige_3    0.262192
# prestige_4    0.211525
# dtype: float64

# %%
np.exp(lm_f.conf_int())
# Out:
#                    0         1
# Intercept   0.002207  0.194440
# gre         1.000074  1.004372
# gpa         1.136120  4.183113
# prestige_2  0.272168  0.942767
# prestige_3  0.133377  0.515419
# prestige_4  0.093329  0.479411

# %% [markdown]
# #### 4.5 Interpret the OR of Prestige_2

# %% [markdown]
# Answer: 0.262192

# %% [markdown]
# #### 4.6 Interpret the OR of GPA

# %% [markdown]
# Answer: 2.18

# %% [markdown]
# ## Part 5: Predicted probabilities

# %% [markdown]
# As a way of evaluating our classifier, we're going to recreate the dataset with every logical combination of input values. This will allow us to see how the predicted probability of admission increases/decreases across different variables. First we're going to generate the combinations using a helper function called cartesian (above).
#
# We're going to use np.linspace to create a range of values for "gre" and "gpa". This creates a range of linearly spaced values from a specified min and maximum value--in our case just the min/max observed values.

# %%
def cartesian(arrays, out=None):
    """
    Generate a cartesian product of input arrays.
    Parameters
    ----------
    arrays : list of array-like
        1-D arrays to form the cartesian product of.
    out : ndarray
        Array to place the cartesian product in.
    Returns
    -------
    out : ndarray
        2-D array of shape (M, len(arrays)) containing cartesian products
        formed of input arrays.
    Examples
    --------
    >>> cartesian(([1, 2, 3], [4, 5], [6, 7]))
    array([[1, 4, 6],
           [1, 4, 7],
           [1, 5, 6],
           [1, 5, 7],
           [2, 4, 6],
           [2, 4, 7],
           [2, 5, 6],
           [2, 5, 7],
           [3, 4, 6],
           [3, 4, 7],
           [3, 5, 6],
           [3, 5, 7]])
    """

    arrays = [np.asarray(x) for x in arrays]
    dtype = arrays[0].dtype

    n = np.prod([x.size for x in arrays])
    if out is None:
        out = np.zeros([n, len(arrays)], dtype=dtype)

    m = n / arrays[0].size
    out[:,0] = np.repeat(arrays[0], m)
    if arrays[1:]:
        cartesian(arrays[1:], out=out[0:m,1:])
        for j in xrange(1, arrays[0].size):
            out[j*m:(j+1)*m,1:] = out[0:m,1:]
    return out

# %%
# instead of generating all possible values of GRE and GPA, we're going
# to use an evenly spaced range of 10 values from the min to the max 
gres = np.linspace(data['gre'].min(), data['gre'].max(), 10)
print gres
# array([ 220.        ,  284.44444444,  348.88888889,  413.33333333,
#         477.77777778,  542.22222222,  606.66666667,  671.11111111,
#         735.55555556,  800.        ])
gpas = np.linspace(data['gpa'].min(), data['gpa'].max(), 10)
print gpas
# array([ 2.26      ,  2.45333333,  2.64666667,  2.84      ,  3.03333333,
#         3.22666667,  3.42      ,  3.61333333,  3.80666667,  4.        ])


# enumerate all possibilities
combos = pd.DataFrame(cartesian([gres, gpas, [1, 2, 3, 4], [1.]]))
# Out:
# [ 220.          284.44444444  348.88888889  413.33333333  477.77777778
#   542.22222222  606.66666667  671.11111111  735.55555556  800.        ]
# [ 2.26        2.45333333  2.64666667  2.84        3.03333333  3.22666667
#   3.42        3.61333333  3.80666667  4.        ]

# %% [markdown]
# #### 5.1 Recreate the dummy variables

# %%
# recreate the dummy variables
dummy_rank = pd.get_dummies(df["prestige"]) 
dummy_rank.columns = ['prestige_1', 'prestige_2', 'prestige_3', 'prestige_4']
df_dummy = df.join(dummy_rank)
df_dummy.drop('prestige', axis=1, inplace=True)
df_dummy
# keep only what we need for making predictions
df_dummy.drop("prestige_1", axis=1, inplace=True)
df_dummy
# Out:
#      admit    gre   gpa  prestige_2  prestige_3  prestige_4
# 0        0  380.0  3.61           0           1           0
# 1        1  660.0  3.67           0           1           0
# 2        1  800.0  4.00           0           0           0
# 3        1  640.0  3.19           0           0           1
# 4        0  520.0  2.93           0           0           1
# 5        1  760.0  3.00           1           0           0
# 6        1  560.0  2.98           0           0           0
# 7        0  400.0  3.08           1           0           0
# 8        1  540.0  3.39           0           1           0
# 9        0  700.0  3.92           1           0           0
# 10       0  800.0  4.00           0           0           1
# 11       0  440.0  3.22           0           0           0
# 12       1  760.0  4.00           0           0           0
# 13       0  700.0  3.08           1           0           0
# 14       1  700.0  4.00           0           0           0
# ...

# %% [markdown]
# #### 5.2 Make predictions on the enumerated dataset

# %%
lm_f = smf.logit(formula = 'admit ~ gre + gpa + prestige_2 + prestige_3 + prestige_4', data=df_dummy)

# %%
lm_f.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-c218eecd785e> in <module>()
# ----> 1 lm_f.summary()
#
# AttributeError: 'Logit' object has no attribute 'summary'

# %% [markdown]
# #### 5.3 Interpret findings for the last 4 observations

# %%
# Really quite lost in this segment
# Out:
# Object `init` not found.

# %% [markdown]
# Answer:

# %% [markdown]
# ## Bonus
#
# Plot the probability of being admitted into graduate school, stratified by GPA and GRE score.
